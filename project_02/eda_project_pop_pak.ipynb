# %% [markdown]
# # Pakistan Population EDA Project(Part-1)

# %% [markdown]
# <img src="pakistan.png" alt="Pakistan" width="80%">

# %% [markdown]
# ## **Auther Name:** Umar Mehmood

# %% [markdown]
# ## Social Media Icons
#
# [LinkedIn](https://www.linkedin.com/in/umar-mehmood-147224294/)
# <br>
# <img src="images.png" alt="LinkedIn" width="50"/>
#
# [Twitter](https://twitter.com/UmarMeh12214006)
# <br>
# <img src="twitter.png" alt="Twitter" width="50"/>
#
# [Kaggle](https://www.kaggle.com/umarmehmood)
# <br>
# <img src="kaggle.png" alt="Kaggle" width="50"/>
#
# [GitHub](https://github.com/Umar885)
# <br>
# <img src="github.png" alt="GitHub" width="50"/>
#
# [Medium](https://medium.com/@umarmehmood885)
# <br>
#
# <img src="medium.png" alt="Medium" width="50"/>
#
# [Email](mailto:umarmehmood885@gmail.com)
# <br>
#
# <img src="email.png" alt="Email" width="50"/>

# %% [markdown]
# The Data was collected from the following [link](https://www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-dataset/data):
#
# **Year of Data:**
# 1. 2017
# 2. 1998

# %% [markdown]
# ## *The Dataset Collected from the Source has following Description:*
# `Description`
# This dataset contains demographic information from the Pakistan Population Census conducted in 2017. It provides detailed population data at various administrative levels within Pakistan, including provinces, divisions, districts, and sub-divisions. The dataset also includes information on urban and rural populations, gender distribution, transgender individuals, sex ratios, population figures from the 1998 census, and annual growth rates.
#
# `Features`
# Province: The administrative provinces or regions of Pakistan where the census data was collected.
#
# Division: The divisions within each province. Divisions are the second level of administrative divisions in Pakistan.
#
# District: Districts within each division, representing larger administrative units.
#
# Sub-Division: Sub-divisions or tehsils within each district, providing more localized data.
#
# Area: The land area (in square kilometers) of each sub-division.
#
# Urban Population 2017: The population of urban areas within each sub-division for the year 2017.
#
# Rural Population 2017: The population of rural areas within each sub-division for the year 2017.
#
# Male Population 2017: The male population within each sub-division for the year 2017.
#
# Female Population 2017: The female population within each sub-division for the year 2017.
#
# Transgender Population 2017: The population of transgender individuals within each sub-division for the year 2017.
#
# Sex Ratio 2017: The sex ratio, calculated as the number of females per 1000 males, within each sub-division for the year 2017.
#
# Population in 1998: The total population of each sub-division as recorded in the 1998 census.
#
# Annual Growth Rate: The annual growth rate of the population in each sub-division, calculated as the percentage increase from 1998 to 2017.
#
# `Data Source`
# The data in this dataset was collected from official Pakistan Population Census reports and may include data from various government sources. It is essential to provide proper attribution and reference the original sources when using this dataset for analysis or research.
#
# `Data Usage`
# Researchers and analysts can use this dataset to explore demographic trends, population growth, urbanization rates, gender distribution, and more within Pakistan at different administrative levels. Ensure compliance with ethical and legal guidelines when using this data for research or public sharing.
#
# Please note that this description is a template, and you should adapt it based on the actual data sources and specific details of your dataset when creating it for Kaggle or any other platform.

# %% [markdown]
# Kernel Version Used
# - python 3.11.0

# %% [markdown]
# ## Purpose of this Anaylsis
# The goal of the Pakistan Population dataset is to provide thorough insights on demographic trends and distribution over different Pakistani areas and time periods.\
# **1.Demographic Data:** Includes age, gender, ethnicity, and household composition information.
#
# **2.Geographic Distribution:** Covers population statistics across provinces, cities, and rural areas.
#
# **3.Temporal Trends:**  Provides time-series data for analyzing population growth, birth and mortality rates, and migration patterns.
#
# **4.Socioeconomic Indicators:** May encompass education levels, employment status, income distribution, and housing conditions

# %% [markdown]
# ## List of Question
# - 1.In Pakistan, how many provinces are there?
# - 2.Pakistan, how many divisions are there?
# - 3.In Pakistan, how many districts are there?
# - 4.Pakistan has how many sub-divisions?
# - 5.Which province has the largest area in Pakistan?
# - 6.How many divisions are there in every Pakistani province?
# - 7.In which province are all genders (rural) higher?
# - 8.What is the distribution of genders in each Pakistani province?
# - 9.What is the average household size in every Pakistani province, both in rural and urban areas?
# - 10.Show the population of Pakistan in each province in 1998
# - 11.Display Pakistan's population (both rural and urban) in 1998.
# - 12.Show Pakistan's sex ratio in both urban and rural areas.

# %% [markdown]
# ## Besic Exploration and Data Cleaning

# %%
# import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# %%
# import the dataset
df = pd.read_excel("/kaggle/input/population-of-pakistan-dataset/population_data.xlsx")

# %% [markdown]
# It would be preferable to show the maximum rows and columns so that we may examine the data in more detail.

# %%
# Max  columns printing options
pd.set_option('display.max_columns', None)

# %%
df.shape
# Out:
# (528, 22)

# %% [markdown]
# The total numbers of rows 528\
# The total numbers of columns 22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  528 non-null    int64
#  1   PROVINCE                    528 non-null    object
#  2   DIVISION                    528 non-null    object
#  3   DISTRICT                    528 non-null    object
#  4   SUB DIVISION                528 non-null    object
#  5   AREA (sq.km)                528 non-null    float64
#  6   ALL SEXES (RURAL)           528 non-null    int64
#  7   MALE (RURAL)                528 non-null    int64
#  8   FEMALE (RURAL)              528 non-null    int64
#  9   TRANSGENDER (RURAL)         528 non-null    int64
#  10  SEX RATIO (RURAL)           528 non-null    float64
#  11  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  12  POPULATION 1998 (RURAL)     528 non-null    int64
# ...

# %% [markdown]
# There are 22 columns and there are no missing values

# %%
# check for first five rows of the dataset
df.head()
# Out:
#    Unnamed: 0 PROVINCE             DIVISION               DISTRICT  \
# 0           0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 1           1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 2           2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 3           3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 4           4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0  BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# 1     CHISHTIAN TEHSIL        1500.0             540342        273788
# 2    FORT ABBAS TEHSIL        2536.0             361240        182655
# 3    HAROONABAD TEHSIL        1295.0             382115        192278
# 4   MINCHINABAD TEHSIL        1818.0             452723        231506
#
#    FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  \
# 0          302644                   42             104.70
# ...

# %%
# check for last five rows of the dataset
df.tail()
# Out:
#      Unnamed: 0  PROVINCE                   DIVISION  \
# 523         523  KPK/FATA  DERA ISMAIL KHAN DIVISION
# 524         524  KPK/FATA  DERA ISMAIL KHAN DIVISION
# 525         525  KPK/FATA  DERA ISMAIL KHAN DIVISION
# 526         526  KPK/FATA  DERA ISMAIL KHAN DIVISION
# 527         527  KPK/FATA  DERA ISMAIL KHAN DIVISION
#
#                       DISTRICT       SUB DIVISION  AREA (sq.km)  \
# 523  SOUTH WAZIRISTAN DISTRICT   SARAROGHA TEHSIL         813.0
# 524  SOUTH WAZIRISTAN DISTRICT    SERWEKAI TEHSIL         398.0
# 525  SOUTH WAZIRISTAN DISTRICT      TIARZA TEHSIL         734.0
# 526  SOUTH WAZIRISTAN DISTRICT  TOI KHULLA TEHSIL         567.0
# 527  SOUTH WAZIRISTAN DISTRICT        WANA TEHSIL        2315.0
#
#      ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  TRANSGENDER (RURAL)  \
# 523              98180         51479           46694                    7
# 524              54540         28695           25844                    1
# ...

# %%
# cross check for null values
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %% [markdown]
# A heatmap that we created demonstrates that there are no missing numbers.

# %%
#HEATMAP
plt.figure(figsize=(25,25))
sns.heatmap(df.isnull(),annot=True)
# Out:
# <Axes: >

# %%
# Summary of statistics
df.describe()
# Out:
#        Unnamed: 0  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# count   528.00000    528.000000       5.280000e+02  5.280000e+02
# mean    263.50000   1492.005871       2.462780e+05  1.252757e+05
# std     152.56474   2039.453778       2.711898e+05  1.375630e+05
# min       0.00000      0.000000       0.000000e+00  0.000000e+00
# 25%     131.75000    425.000000       5.093450e+04  2.712725e+04
# 50%     263.50000    882.000000       1.652410e+05  8.413450e+04
# 75%     395.25000   1734.250000       3.129112e+05  1.605022e+05
# max     527.00000  18374.000000       2.297375e+06  1.172995e+06
#
#        FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  \
# count    5.280000e+02           528.000000         528.000000
# mean     1.209841e+05            18.174242          98.982614
# std      1.337169e+05            25.522248          26.812660
# min      0.000000e+00             0.000000           0.000000
# 25%      2.397900e+04             1.000000         101.105000
# ...

# %% [markdown]
# There are show the summary of whole dataset

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION',
#        'AREA (sq.km)', 'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %% [markdown]
# Show the all columns name

# %% [markdown]
# Question 1. In Pakistan, how many provinces are there?

# %%
df['PROVINCE'].unique()
# Out:
# array(['PUNJAB', 'SINDH', 'BALOCHISTAN', 'KPK', 'KPK/FATA'], dtype=object)

# %%
fig = px.pie(df, names="PROVINCE")
fig.show()

# %% [markdown]
# **Interpretation**\
# Data Context:With a focus on Pakistan's five component provinces—Punjab, Sindh, Balochistan, Khyber Pakhtunkhwa (KPK), and KPK/FATA—the pie chart and barplot illustrate the country's geographical divisions.\
# Punjab: It is regarded as the largest province, encompassing a substantial portion of territory—roughly 27.1% of all of Pakistan's land area.\
# Other Provinces:Based on land area, the provinces are ranked as follows Sindh is at 25.9%, Balochistan is at 24.8%, KPK is at 13.4%, and KPK/FATA is at 8.71%.

# %% [markdown]
# **Answer**. There are five provinces in Pakistan, Balochistan, Sindh, Punjab, KPK, & KPK/FATA

# %% [markdown]
# **Question 2**.Pakistan, how many divisions are there?

# %%
df['DIVISION'].unique()
# Out:
# array(['BAHAWALPUR DIVISION', 'D.G.KHAN DIVISION', 'FAISALABAD DIVISION',
#        'GUJRANWALA DIVISION', 'LAHORE DIVISION', 'MULTAN DIVISION',
#        'RAWALPINDI DIVISION', 'SAHIWAL DIVISION', 'SARGODHA DIVISION',
#        'Badin Division', 'Hyderabad Division', 'Karachi Division',
#        'Larkana Division', 'Mirpurkhas Division',
#        'Shaheed Benazirabad Division', 'Sukkur Division',
#        'Makran Division', 'Kalat Division', 'Naseerabad Division',
#        'Quetta Division', 'Zhob Division', 'BANNU DIVISION',
#        'DERA ISMAIL KHAN DIVISION', 'HAZARA DIVISION', 'KOHAT DIVISION',
#        'MARDAN DIVISION', 'PESHAWAR DIVISION', 'MALAKAND DIVISION'],
#       dtype=object)

# %%
df['DIVISION'].nunique()
# Out:
# 28

# %%
fig = px.pie(df, names="DIVISION")
fig.show()

# %% [markdown]
# ***Answer.*** Pakistan is divided into 28 divisions in total.

# %% [markdown]
# **Question 3**. In Pakistan, how many districts are there?

# %%
df['DISTRICT'].unique()
# Out:
# array(['BAHAWALNAGAR DISTRICT', 'BAHAWALPUR DISTRICT',
#        'RAHIM YAR KHAN DISTRICT', 'DERA GHAZI KHAN DISTRICT',
#        'LAYYAH DISTRICT', 'MUZAFFARGARH DISTRICT', 'RAJANPUR DISTRICT',
#        'CHINIOT DISTRICT', 'FAISALABAD DISTRICT', 'JHANG DISTRICT',
#        'TOBA TEK SINGH DISTRICT', 'GUJRANWALA DISTRICT',
#        'GUJRAT DISTRICT', 'HAFIZABAD DISTRICT',
#        'MANDI BAHAUDDIN DISTRICT', 'NAROWAL DISTRICT', 'SIALKOT DISTRICT',
#        'KASUR DISTRICT', 'LAHORE DISTRICT', 'NANKANA SAHIB DISTRICT',
#        'SHEIKHUPURA DISTRICT', 'KHANEWAL DISTRICT', 'LODHRAN DISTRICT',
#        'MULTAN DISTRICT', 'VEHARI DISTRICT', 'ATTOCK DISTRICT',
#        'CHAKWAL DISTRICT', 'JHELUM DISTRICT', 'RAWALPINDI DISTRICT',
#        'OKARA DISTRICT', 'PAKPATTAN DISTRICT', 'SAHIWAL DISTRICT',
#        'BHAKKAR DISTRICT', 'KHUSHAB DISTRICT', 'MIANWALI DISTRICT',
#        'SARGODHA DISTRICT', 'BADIN DISTRICT', 'DADU DISTRICT',
# ...

# %%
df['DISTRICT'].nunique()
# Out:
# 131

# %% [markdown]
# **Answer**. Pakistan 131 Districts, due to huge number we can't visualize it

# %% [markdown]
# **Question 4**.Pakistan has how many sub-divisions?

# %%
df['SUB DIVISION'].unique()
# Out:
# array(['BAHAWALNAGAR TEHSIL', 'CHISHTIAN TEHSIL', 'FORT ABBAS TEHSIL',
#        'HAROONABAD TEHSIL', 'MINCHINABAD TEHSIL', 'AHMADPUR EAST TEHSIL',
#        'BAHAWALPUR CITY TEHSIL', 'BAHAWALPUR SADDAR TEHSIL',
#        'HASILPUR TEHSIL', 'KHAIRPUR TAMEWALI TEHSIL', 'YAZMAN TEHSIL',
#        'KHANPUR TEHSIL', 'LIAQUATPUR TEHSIL', 'RAHIM YAR KHAN TEHSIL',
#        'SADIQABAD TEHSIL', 'DE-EXCLUDED AREA D.G KHAN',
#        'DERA GHAZI KHAN TEHSIL', 'KOT CHHUTTA TEHSIL', 'TAUNSA TEHSIL',
#        'CHOUBARA TEHSIL', 'LAYYAH TEHSIL', 'ALIPUR TEHSIL',
#        'JATOI TEHSIL', 'KOT ADDU TEHSIL', 'MUZAFFARGARH TEHSIL',
#        'DE-EXCLUDED AREA RAJANPUR', 'JAMPUR TEHSIL', 'RAJANPUR TEHSIL',
#        'ROJHAN TEHSIL', 'BHAWANA TEHSIL', 'CHINIOT TEHSIL',
#        'LALIAN TEHSIL', 'CHAK JHUMRA TEHSIL', 'FAISALABAD CITY TEHSIL',
#        'FAISALABAD SADAR TEHSIL', 'JARANWALA TEHSIL', 'SAMMUNDRI TEHSIL',
#        'TANDLIAN WALA TEHSIL', '18-HAZARI TEHSIL', 'AHMADPUR SIAL TEHSIL',
# ...

# %%
df['SUB DIVISION'].nunique()
# Out:
# 528

# %% [markdown]
# **Answer**. Pakistan is divided into 528 subdivisons.

# %% [markdown]
# **Question 5**. Which province has the largest area in Pakistan?

# %%
# Use groupby function
area_sqr = df.groupby('PROVINCE')['AREA (sq.km)'].mean().sort_values(ascending=False)
area_sqr
# Out:
# PROVINCE
# BALOCHISTAN    2637.129771
# PUNJAB         1417.433566
# KPK            1055.733803
# SINDH          1022.890511
# KPK/FATA        533.239130
# Name: AREA (sq.km), dtype: float64

# %%
fig = px.bar(area_sqr, x=area_sqr.index, y='AREA (sq.km)', title="Average Area of each Province", color=area_sqr.values)
fig.show()

# %% [markdown]
# **Interpretation**\
# This interpretation does a good job of summarizing the data shown in the graph. It shows the land areas of Pakistan's provinces, with the largest land area being Balochistan(2637.129771), followed by Punjab(1417.433566), KPK(1055.733803), Sindh(1022.890511), and KPK/FATA(533.239130). Understanding the distribution of land areas among the provinces is made easier by the addition of mean values. Overall, the data shown in the graph is summarized in a clear and straightforward manner by this interpretation.

# %% [markdown]
# **Answer**. Balochistan(2637.129771) is the largest province of Pakistan by square area

# %% [markdown]
# **Question 6**. How many divisions are there in every Pakistani province?

# %%
#Divisions in each province
division = df.groupby('PROVINCE')['DIVISION'].nunique()

division
print("Divisions in each province:", division)
# Out:
# Divisions in each province: PROVINCE
# BALOCHISTAN    5
# KPK            7
# KPK/FATA       5
# PUNJAB         9
# SINDH          7
# Name: DIVISION, dtype: int64

# %%
fig = px.bar(division, x=division.index, y='DIVISION', title="Divisions in each Province", color=division.index)
fig.show()

# %% [markdown]
# **Interpretation**\
# The bar graph demonstrates the divisional distribution across provinces in Pakistan. A comprehensive analysis reveals a total of 33 divisions within the country. Punjab leads with 9 divisions, followed closely by Khyber Pakhtunkhwa (KPK) and Sindh, each with 7 divisions. Balochistan and KPK/FATA have 5 divisions each within their boundaries.

# %% [markdown]
# **Answer**. Pakistan is divided into 33 divisions: Punjab (9), KPK (7), Sindh (7), Balochistan (5), and KPK/FATA (5).

# %% [markdown]
# **Question 7**. In which province are all genders (rural) higher?

# %%
# check this populatin in each Province
all_sexes_rural = df.groupby('PROVINCE')['ALL SEXES (RURAL)'].sum().sort_values(ascending=False)
all_sexes_rural
# Out:
# PROVINCE
# PUNJAB         68662922
# KPK            24892840
# SINDH          23011641
# BALOCHISTAN     8879634
# KPK/FATA        4587753
# Name: ALL SEXES (RURAL), dtype: int64

# %%
fig = px.bar(all_sexes_rural, x=all_sexes_rural.index, y='ALL SEXES (RURAL)', title="Population in each Province", color=all_sexes_rural.index)
fig.show()

# %% [markdown]
# **Interpretation**\
# The bar graph illustrates the distribution of rural population across provinces in Pakistan, specifically focusing on the "All Sexes (Rural)" demographic. Upon analysis, the total rural population within the country is found to be 130,034,790. Punjab emerges as the province with the highest rural population, totaling 68,662,922. Following closely, Khyber Pakhtunkhwa (KPK) has a rural population of 24,892,840, and Sindh has 23,011,641 rural inhabitants. Balochistan's rural population is reported to be 8,879,634, while KPK/FATA has a rural population of 4,587,753.

# %% [markdown]
# **Answer**. Punjab( 68662922) has the largest population of all genders in Pakistan.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION',
#        'AREA (sq.km)', 'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %% [markdown]
# Show top 20 DIVISION AVG HOUSEHOLD SIZE (RURAL) in provinces of Pakistan

# %%
# Calculate the Avg household size of each division and select the top 20
top_20_household = df.groupby('DIVISION')['AVG HOUSEHOLD SIZE (RURAL)'].mean().sort_values(ascending=False).head(20)

top_20_household

fig = px.bar(top_20_household, x=top_20_household.index, y='AVG HOUSEHOLD SIZE (RURAL)', title="Top 20 Division Avg Household Size (Rural)", color=top_20_household.index)
fig.show()

# %% [markdown]
# Show top 20 DISTRICT AVG HOUSEHOLD SIZE (RURAL) in provinces of Pakistan

# %%
# Calculate the Avg household size of each District and select the top 20
top_20_household = df.groupby('DISTRICT')['AVG HOUSEHOLD SIZE (RURAL)'].mean().sort_values(ascending=False).head(20)

top_20_household
fig = px.bar(top_20_household, x=top_20_household.index, y='AVG HOUSEHOLD SIZE (RURAL)', title="Top 20 District Avg Household Size (Rural)", color=top_20_household.index)
fig.show()

# %% [markdown]
# Show top 20 SUB DIVISION AVG HOUSEHOLD SIZE (RURAL) in provinces of Pakistan

# %%
# Calculate the Avg household size of each Sub Division and select the top 20
top_20_household = df.groupby('SUB DIVISION')['AVG HOUSEHOLD SIZE (RURAL)'].mean().sort_values(ascending=False).head(20)

top_20_household
fig = px.bar(top_20_household, x=top_20_household.index, y='AVG HOUSEHOLD SIZE (RURAL)', title="Top 20 Sub Division Avg Household Size (Rural)", color=top_20_household.index)
fig.show()

# %% [markdown]
# **Question 8**. What is the distribution of genders in each Pakistani province?

# %%
# Select the columns of interest
columns_of_interest = ['MALE (RURAL)', 'MALE (URBAN)', 'FEMALE (RURAL)', 'FEMALE (URBAN)', 'TRANSGENDER (RURAL)', 'TRANSGENDER (URBAN)', 'PROVINCE']
df_gender_province = df[columns_of_interest]

# Reshape the DataFrame using melt function
melted_df = pd.melt(df_gender_province, id_vars='PROVINCE', var_name='Gender', value_name='value')

# Display the reshaped DataFrame
print(melted_df)
# Out:
#       PROVINCE               Gender   value
# 0       PUNJAB         MALE (RURAL)  316864
# 1       PUNJAB         MALE (RURAL)  273788
# 2       PUNJAB         MALE (RURAL)  182655
# 3       PUNJAB         MALE (RURAL)  192278
# 4       PUNJAB         MALE (RURAL)  231506
# ...        ...                  ...     ...
# 3163  KPK/FATA  TRANSGENDER (URBAN)       0
# 3164  KPK/FATA  TRANSGENDER (URBAN)       0
# 3165  KPK/FATA  TRANSGENDER (URBAN)       0
# 3166  KPK/FATA  TRANSGENDER (URBAN)       0
# 3167  KPK/FATA  TRANSGENDER (URBAN)       0
#
# [3168 rows x 3 columns]

# %%
fig = px.bar(melted_df, x='PROVINCE', y='value', color='Gender', barmode='group', title="Gender Distribution in each Province")
fig.show()

# %% [markdown]
# **Interpretation**\
# `Gender Distribution Analysis in Pakistan's Provinces:`
# The above bar graph, which focuses on the demographics of men, women, and transgender people in both rural and urban environments, shows how gender is distributed throughout five provinces of Pakistan.\
# `1.Distribution Discrepancy:`
# When comparing rural to urban envirThis disparity suggests that living in a rural area and having less access to educational resources may be related, especially when it comes to family planning.onments, there is a discernible concentration of both male and female populations.\
# `2.Transgender Representation:`
# It is less evident in the graph as the transgender group has a less marked concentration.\
# `3.Regional Insights:`
# In rural areas, the highest concentrations of male and female persons are found in Punjab and Khyber Pakhtunkhwa (KPK).
# Sindh exhibits a comparatively homogeneous distribution in both urban and rural environments.
# Balochistan is the region with the highest concentration of male and female population in KPK/Federally Administered Tribal Areas (FATA) rural areas

# %% [markdown]
# **Answer**. This code will generate a bar chart that visualizes the distribution of genders (male, female, transgender) in each Pakistani province.

# %% [markdown]
# **Question 9**. What is the average household size in every Pakistani province, both in rural and urban areas?

# %%
# Select the columns of interest
columns_of_household = ['AVG HOUSEHOLD SIZE (RURAL)', 'AVG HOUSEHOLD SIZE (URBAN)', 'PROVINCE']

# Reshape the DataFrame using melt function

melted_df = pd.melt(df[columns_of_household], id_vars='PROVINCE', var_name='Area', value_name='value')
# Display the reshaped DataFrame
print(melted_df)


# Create a new column called "Area" in the melted DataFrame
# Out:
#       PROVINCE                        Area  value
# 0       PUNJAB  AVG HOUSEHOLD SIZE (RURAL)   6.10
# 1       PUNJAB  AVG HOUSEHOLD SIZE (RURAL)   6.15
# 2       PUNJAB  AVG HOUSEHOLD SIZE (RURAL)   6.32
# 3       PUNJAB  AVG HOUSEHOLD SIZE (RURAL)   6.15
# 4       PUNJAB  AVG HOUSEHOLD SIZE (RURAL)   6.29
# ...        ...                         ...    ...
# 1051  KPK/FATA  AVG HOUSEHOLD SIZE (URBAN)   0.00
# 1052  KPK/FATA  AVG HOUSEHOLD SIZE (URBAN)   0.00
# 1053  KPK/FATA  AVG HOUSEHOLD SIZE (URBAN)   0.00
# 1054  KPK/FATA  AVG HOUSEHOLD SIZE (URBAN)   0.00
# 1055  KPK/FATA  AVG HOUSEHOLD SIZE (URBAN)   0.00
#
# [1056 rows x 3 columns]

# %%
fig = px.bar(melted_df, x='PROVINCE', y='value', color= 'Area', barmode='group', title="Household Size Distribution in each Province")

fig.show()

# %% [markdown]
# **Interpretation**\
# `Analysis of Average Household Size in Pakistan's Provinces`:The provided bar graph presents data on the average household size in rural and urban areas across five provinces of Pakistan.\
# `Key Points:`\
# `1.Trend Overview:`
# - In all provinces, average numbers of people living in rural homes are higher than in urban ones.
# - Punjab is an anomaly, with the average number of people living in both rural and urban homes being the same at 6.15.
#
# `2.Provincial Comparisons:`
# - Sindh shows a marginal decrease in household size compared to urban areas.
# - Balochistan, Khyber Pakhtunkhwa (KPK), and KPK/Federally Administered Tribal Areas (FATA) exhibit a notable divergence.
# - Rural households in these provinces have a substantial increase in size compared to urban households, indicating significant differences in living arrangements.

# %% [markdown]
# **Answer**. This code will generate a bar chart that visualizes the average household size in every Pakistani province, both in rural and urban areas.

# %% [markdown]
# **Question 10**. Show the population of Pakistan in each province in 1998

# %%
# # Your existing code
pak_pop_1998 = df[['PROVINCE', 'POPULATION 1998 (RURAL)', 'POPULATION 1998 (URBAN)']]


# Reshape the DataFrame using melt function
melted_df = pd.melt(pak_pop_1998, id_vars='PROVINCE', var_name='Population', value_name='value')

# Display the reshaped DataFrame
print(melted_df)
# Out:
#       PROVINCE               Population   value
# 0       PUNJAB  POPULATION 1998 (RURAL)  407768
# 1       PUNJAB  POPULATION 1998 (RURAL)  395983
# 2       PUNJAB  POPULATION 1998 (RURAL)  250959
# 3       PUNJAB  POPULATION 1998 (RURAL)  297343
# 4       PUNJAB  POPULATION 1998 (RURAL)  316593
# ...        ...                      ...     ...
# 1051  KPK/FATA  POPULATION 1998 (URBAN)       0
# 1052  KPK/FATA  POPULATION 1998 (URBAN)       0
# 1053  KPK/FATA  POPULATION 1998 (URBAN)       0
# 1054  KPK/FATA  POPULATION 1998 (URBAN)       0
# 1055  KPK/FATA  POPULATION 1998 (URBAN)       0
#
# [1056 rows x 3 columns]

# %%
fig = px.bar(melted_df, x='PROVINCE', y='value', color='Population', barmode='group', title="Population Distribution in each Province", color_discrete_sequence=px.colors.qualitative.Bold, text_auto='.2s', labels={'value': 'Population'}, hover_data={'value': ':.2f'}, template='plotly_white', width=700, height=500, orientation='v', text='value', color_discrete_map={'POPULATION 1998 (RURAL)': 'red', 'POPULATION 1998 (URBAN)': 'blue'})

fig.show()

# %% [markdown]
# **Question 11**. Display Pakistan's population (both rural and urban) in 1998.

# %%
# calculate mean of the population in 1998 rural vs urban
print("Population of rural in 1998:", df['POPULATION 1998 (RURAL)'].mean())
print("Population of urban in 1998:", df['POPULATION 1998 (URBAN)'].mean())
# Out:
# Population of rural in 1998: 167427.99431818182
# Population of urban in 1998: 80144.56628787878

# %%
pop_1998 = pd.DataFrame({'Rural Population (1998)':[167427.99],
                         'Urban population (1998)':[80144.56]})
pop_1998
# Out:
#    Rural Population (1998)  Urban population (1998)
# 0                167427.99                 80144.56

# %%
# Use the melt function to reshape the data
pop_1998 = pd.melt(pop_1998,  var_name='Population', value_name='value')

# Display the reshaped DataFrame
print(pop_1998)
# Out:
#                 Population      value
# 0  Rural Population (1998)  167427.99
# 1  Urban population (1998)   80144.56

# %%
fig = px.bar(pop_1998, x='Population', y='value', title="Population Distribution in 1998", color='Population', color_discrete_map={'Rural Population (1998)': 'red', 'Urban population (1998)': 'blue'})

fig.show()

# %% [markdown]
# **Interpretation**\
# `Population Distribution Analysis in 1998:`
# The below code snippet creates a bar plot that shows the population distribution in 1998 using Plotly Express (px). With the x-axis indicating various population groups, the y-axis representing population numbers, and colors designating rural and urban populations, the plot shows the population data included in the DataFrame pop 1998.\
# `Population Statistics:`
# - Population of rural areas in 1998: 167,427.99
# - Population of urban areas in 1998: 80,144.57

# %% [markdown]
# **Answer**. display Pakistan's population in both rural and urban areas in 1998, you can calculate the total population for each area and then display the values.

# %% [markdown]
# **Question 12**. Show Pakistan's sex ratio in both urban and rural areas.

# %%
# Calculate mean sex ratio for rural and urban populations in 1998
sex_ratio_rural = np.mean(df['SEX RATIO (RURAL)'])
sex_ratio_urban = np.mean(df['SEX RATIO (URBAN)'])

# Create a DataFrame for sex ratios
sex_ratio = pd.DataFrame({
    'Sex Ratio': ['Rural', 'Urban'],
    'Mean': [sex_ratio_rural, sex_ratio_urban]
})
# Reshape the DataFrame using melt
sex_ratio_melted = sex_ratio.melt(id_vars='Sex Ratio', value_vars='Mean', var_name='Statistic', value_name='Value')
print(sex_ratio_melted)
# Out:
#   Sex Ratio Statistic      Value
# 0     Rural      Mean  98.982614
# 1     Urban      Mean  75.411269

# %%
# Create a bar chart using Plotly Express
fig = px.bar(sex_ratio_melted, x='Sex Ratio', y='Value', color='Sex Ratio', title="Sex Ratio in Rural and Urban", color_discrete_map={'Rural': 'red', 'Urban': 'blue'},  width=600, height=500)

fig.show()

# %% [markdown]
# **Answer**. Pakistan's sex ratio is the highest in rural areas compared to urban areas

# %% [markdown]
# **Interpretation**\
#  `Sex Ratio in Rural and Urban:`
#  The provided bar graph presents data on the sex ratio in rural and urban areas across five provinces of Pakistan.
#
# The graph shows the ratio of males to females in rural and urban areas. The data is collected from a survey conducted by the government ag
# The graph shows the sex ratio of births in rural areas compared to urban areas. The x-axis represents different years, while the y-
# In the given data, there is a significant difference between the sex ratio in rural and urban areas. The female to male ratio (FRM)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# I am pleased to announce the successful completion of an extensive data analysis project centered on Pakistan's population from 1998 to 2017. I kindly request your support through an upvote. Your positive feedback would be immensely encouraging and would validate the valuable insights I have unearthed during this endeavor. Your support is highly valued and will serve as a motivating force for my future contributions to the field of data analysis. Thank you sincerely for your time and consideration.
