# %%
# import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# import the dataset
df = pd.read_csv("googleplaystore.csv")

# %%
# run autometic eda using ydata_profiling library
#import ydata_profiling as yd
#profiling = yd.ProfileReport(df)

#profiling.to_file(output_file="04_googleplaystore_eda_kaggle.html")
# Out:
# Summarize dataset:  75%|███████▌  | 15/20 [00:03<00:00,  5.44it/s, Calculate auto correlation]     c:\Users\Kashif\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: '4.0.3 and up'')
#   warnings.warn(
# Summarize dataset:  79%|███████▉  | 19/24 [00:05<00:00,  5.40it/s, Missing diagram heatmap]   c:\Users\Kashif\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
# ...

# %%
# check this data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
#  13  Unnamed: 13     0 non-null      float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
# lets have a looks on a dataset
df.head()
# Out:
#                                        App       Category  Rating   Reviews  \
# 0  Life Made WI-Fi Touchscreen Photo Frame            NaN     1.9        19
# 1                                 Facebook         SOCIAL     4.1  78158306
# 2                                 Facebook         SOCIAL     4.1  78128208
# 3                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 4                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
#
#                  Size        Installs  Type Price Content Rating  \
# 0                3.0M          1,000+  Free     0       Everyone
# 1  Varies with device  1,000,000,000+  Free     0           Teen
# 2  Varies with device  1,000,000,000+  Free     0           Teen
# 3  Varies with device  1,000,000,000+  Free     0       Everyone
# 4  Varies with device  1,000,000,000+  Free     0       Everyone
#
#           Genres       Last Updated         Current Ver         Android Ver  \
# ...

# %%
# take sample from big dataset
df.sample(10)
# Out:
#                                 App             Category  Rating  Reviews  \
# 4862                      PlugShare  MAPS_AND_NAVIGATION     4.7     4501
# 6896          DV Lottery Photo Tool          PHOTOGRAPHY     4.0      223
# 3927                     Diabetes:M              MEDICAL     4.6    15537
# 9994      Android P Style Icon Pack      PERSONALIZATION     5.0        1
# 2276        Ada - Your Health Guide              MEDICAL     4.7    87418
# 1660  FlipaClip - Cartoon animation       ART_AND_DESIGN     4.3   194216
# 9610                AF Johannesburg               FAMILY     NaN        3
# 8691                         BJ-FPV               FAMILY     4.2       16
# 5770               F-Secure AV Test                TOOLS     4.5     1250
# 9213                        DM 24/7                TOOLS     3.6        7
#
#                     Size    Installs  Type  Price Content Rating  \
# 4862                 26M    100,000+  Free      0           Teen
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews  Unnamed: 13
# count  9367.000000  1.084100e+04          0.0
# mean      4.191513  4.441119e+05          NaN
# std       0.515735  2.927629e+06          NaN
# min       1.000000  0.000000e+00          NaN
# 25%       4.000000  3.800000e+01          NaN
# 50%       4.300000  2.094000e+03          NaN
# 75%       4.500000  5.476800e+04          NaN
# max       5.000000  7.815831e+07          NaN

# %% [markdown]
# # Assignment: write down all the numeric variables and make them numeric
# 1. size
# 2. install
# 3. price

# %%
# To do that lets have a look on unique values
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 976k                     1
# 8.5k                     1
# 221k                     1
# 371k                     1
# 1020k                    1
# Name: count, Length: 461, dtype: int64

# %% [markdown]
# # check that how many MBs are there in one kB? and how to calculate
# 1. Convert KBs into M
# 2. Then remove M from all numbers
# 3. Handle `varies with device`

# %%
# check that how many MBs are there in one kB? and how to calculate
print(1024/1024, "MBs in one kB") # 1 MB in 1024 kB
 
 # convert to MBs from bytes.
bytes = 5 * 1024 * 1024

print(bytes, "bytes in one MB") # 5 MB in 1024 kB

# %%
# So check this missing values in size column
df['Size'].isnull().sum()
# Out:
# 0

# %% [markdown]
# do it as numeric column or group that into different group following bining method

# %% [markdown]
# # How to Dealing with Price column

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
#            ...
# $19.40         1
# $3.08          1
# $379.99        1
# $2.56          1
# $1.04          1
# Name: count, Length: 92, dtype: int64

# %%
# check this missing values in price column
df['Price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Remove $ sign from all columns using pandas
