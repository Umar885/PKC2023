# %%
# import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# import the dataset
df = pd.read_csv("googleplaystore.csv")

# %%
# run autometic eda using ydata_profiling library
#import ydata_profiling as yd
#profiling = yd.ProfileReport(df)

#profiling.to_file(output_file="04_googleplaystore_eda_kaggle.html")

# %%
# check this data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
#  13  Unnamed: 13     0 non-null      float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
# lets have a looks on a dataset
df.head()
# Out:
#                                        App       Category  Rating   Reviews  \
# 0  Life Made WI-Fi Touchscreen Photo Frame            NaN     1.9        19
# 1                                 Facebook         SOCIAL     4.1  78158306
# 2                                 Facebook         SOCIAL     4.1  78128208
# 3                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 4                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
#
#                  Size        Installs  Type Price Content Rating  \
# 0                3.0M          1,000+  Free     0       Everyone
# 1  Varies with device  1,000,000,000+  Free     0           Teen
# 2  Varies with device  1,000,000,000+  Free     0           Teen
# 3  Varies with device  1,000,000,000+  Free     0       Everyone
# 4  Varies with device  1,000,000,000+  Free     0       Everyone
#
#           Genres       Last Updated         Current Ver         Android Ver  \
# ...

# %%
# take sample from big dataset
df.sample(10)
# Out:
#                                      App            Category  Rating  Reviews  \
# 8586  Camping and Co - Camping in Europe    TRAVEL_AND_LOCAL     3.7       19
# 6062                           BM Wallet             FINANCE     4.2      798
# 7787                           cx-33wifi              FAMILY     4.4       63
# 8709          Tricky Bike Stunt Rider DX              FAMILY     4.4       16
# 6037                       Verdad o Reto              SOCIAL     3.8      826
# 6805        WiseBanyan - Invest For Free             FINANCE     4.2      257
# 7146                      X-Plane to GPS               TOOLS     4.2      161
# 3833       Hotels Combined - Cheap deals    TRAVEL_AND_LOCAL     4.1    17202
# 5541                               HPlus  HEALTH_AND_FITNESS     2.9     1786
# 556           DINO HUNTER: DEADLY SHORES                GAME     4.4  1381820
#
#       Size     Installs  Type  Price Content Rating                Genres  \
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews  Unnamed: 13
# count  9367.000000  1.084100e+04          0.0
# mean      4.191513  4.441119e+05          NaN
# std       0.515735  2.927629e+06          NaN
# min       1.000000  0.000000e+00          NaN
# 25%       4.000000  3.800000e+01          NaN
# 50%       4.300000  2.094000e+03          NaN
# 75%       4.500000  5.476800e+04          NaN
# max       5.000000  7.815831e+07          NaN

# %% [markdown]
# # Assignment: write down all the numeric variables and make them numeric
# 1. size
# 2. install
# 3. price

# %%
# To do that lets have a look on unique values
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 976k                     1
# 8.5k                     1
# 221k                     1
# 371k                     1
# 1020k                    1
# Name: count, Length: 461, dtype: int64

# %% [markdown]
# # check that how many MBs are there in one kB? and how to calculate
# 1. Convert KBs into M
# 2. Then remove M from all numbers
# 3. Handle `varies with device`

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Unnamed: 13'],
#       dtype='object')

# %%
df
# Out:
#                                            App            Category  Rating  \
# 0      Life Made WI-Fi Touchscreen Photo Frame                 NaN     1.9
# 1                                     Facebook              SOCIAL     4.1
# 2                                     Facebook              SOCIAL     4.1
# 3                           WhatsApp Messenger       COMMUNICATION     4.4
# 4                           WhatsApp Messenger       COMMUNICATION     4.4
# ...                                        ...                 ...     ...
# 10836                                 FQ India           LIFESTYLE     NaN
# 10837                                  Miss FQ  NEWS_AND_MAGAZINES     NaN
# 10838                     Word Search Tab 1 FR              FAMILY     NaN
# 10839                                PLMGSS FR        PRODUCTIVITY     NaN
# 10840                                 FR Forms            BUSINESS     NaN
#
#         Reviews                Size        Installs  Type  Price  \
# ...

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 976k                     1
# 8.5k                     1
# 221k                     1
# 371k                     1
# 1020k                    1
# Name: count, Length: 461, dtype: int64

# %%
# So check this missing values in size column
df['Size'].isnull().sum()
# Out:
# 0

# %% [markdown]
# do it as numeric column or group that into different group following bining method

# %% [markdown]
# # How to Dealing with Price column

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
#            ...
# $19.40         1
# $3.08          1
# $379.99        1
# $2.56          1
# $1.04          1
# Name: count, Length: 92, dtype: int64

# %%
# check this missing values in price column
df['Price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Remove $ sign from all columns using pandas

# %%
df['Installs'].unique()
# Out:
# array(['1,000+', '1,000,000,000+', '100,000,000+', '500,000,000+',
#        '50,000,000+', '10,000,000+', '5,000,000+', '1,000,000+',
#        '500,000+', '100,000+', '50,000+', '10,000+', '5,000+', '500+',
#        '100+', '10+', '50+', '5+', '1+', '0+', '0'], dtype=object)

# %%
df['Installs'] = df['Installs'].str.split('+').str[0]  # Remove the + sign
df['Installs'].replace(',', '', regex=True, inplace=True)  # Remove the commas '.' in the install column
df['Installs'] = df['Installs'].astype(int)  # Convert the install column to integer
# Out:
# C:\Users\Kashif\AppData\Local\Temp\ipykernel_19736\979426842.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Installs'].replace(',', '', regex=True, inplace=True)  # Remove the commas '.' in the install column

# %%
df['Installs'].unique()
# Out:
# array([      1000, 1000000000,  100000000,  500000000,   50000000,
#          10000000,    5000000,    1000000,     500000,     100000,
#             50000,      10000,       5000,        500,        100,
#                10,         50,          5,          1,          0])

# %%
df['Size'].unique()
# Out:
# array(['3.0M', 'Varies with device', '98M', '76M', '97M', '74M', '40M',
#        '52M', '14M', '15M', '88M', '24M', '85M', '94M', '99M', '63M',
#        '92M', '17M', '62M', '71M', '70M', '34M', '95M', '67M', '58M',
#        '100M', '59M', '53M', '96M', '16M', '26M', '41M', '9.9M', '51M',
#        '32M', '11M', '55M', '60M', '79M', '69M', '42M', '77M', '57M',
#        '82M', '75M', '36M', '3.3M', '68M', '22M', '7.6M', '50M', '33M',
#        '7.4M', '89M', '18M', '25M', '78M', '46M', '49M', '9.7M', '37M',
#        '72M', '39M', '87M', '6.1M', '5.1M', '28M', '29M', '61M', '7.1M',
#        '48M', '21M', '35M', '54M', '12M', '56M', '3.8M', '8.7M', '91M',
#        '27M', '45M', '66M', '31M', '4.7M', '8.2M', '43M', '13M', '47M',
#        '20M', '80M', '6.6M', '3.1M', '6.5M', '9.1M', '30M', '7.9M',
#        '4.2M', '44M', '4.4M', '93M', '8.9M', '83M', '3.5M', '73M', '90M',
#        '9.8M', '19M', '9.2M', '64M', '1.5M', '5.2M', '23M', '5.3M',
# ...

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else  x)

# %%
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', ''))/1000 if 'k' in str(x) else  x)

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace(',', '.') if ',' in str(x)    else  x)

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else  x)

# %%
# Conversion Data Gbs to MB
df['Size'] = df['Size'].apply(lambda x: (str(x).replace('G', ''))/1000 if 'G' in str(x) else  x)

# %%
df['Size'] = df['Size'].apply(lambda x: float(x))

# %%
df.dtypes['Size']
# Out:
# dtype('float64')

# %%
df['Size'].unique()
# Out:
# array([3.00e+00,      nan, 9.80e+01, 7.60e+01, 9.70e+01, 7.40e+01,
#        4.00e+01, 5.20e+01, 1.40e+01, 1.50e+01, 8.80e+01, 2.40e+01,
#        8.50e+01, 9.40e+01, 9.90e+01, 6.30e+01, 9.20e+01, 1.70e+01,
#        6.20e+01, 7.10e+01, 7.00e+01, 3.40e+01, 9.50e+01, 6.70e+01,
#        5.80e+01, 1.00e+02, 5.90e+01, 5.30e+01, 9.60e+01, 1.60e+01,
#        2.60e+01, 4.10e+01, 9.90e+00, 5.10e+01, 3.20e+01, 1.10e+01,
#        5.50e+01, 6.00e+01, 7.90e+01, 6.90e+01, 4.20e+01, 7.70e+01,
#        5.70e+01, 8.20e+01, 7.50e+01, 3.60e+01, 3.30e+00, 6.80e+01,
#        2.20e+01, 7.60e+00, 5.00e+01, 3.30e+01, 7.40e+00, 8.90e+01,
#        1.80e+01, 2.50e+01, 7.80e+01, 4.60e+01, 4.90e+01, 9.70e+00,
#        3.70e+01, 7.20e+01, 3.90e+01, 8.70e+01, 6.10e+00, 5.10e+00,
#        2.80e+01, 2.90e+01, 6.10e+01, 7.10e+00, 4.80e+01, 2.10e+01,
#        3.50e+01, 5.40e+01, 1.20e+01, 5.60e+01, 3.80e+00, 8.70e+00,
#        9.10e+01, 2.70e+01, 4.50e+01, 6.60e+01, 3.10e+01, 4.70e+00,
# ...

# %% [markdown]
# | Social Media | Link |
# |--------------|------|
# | Facebook     | <a href="https://www.facebook.com/" style="color: #3b5998;">Facebook</a> |
# | Twitter      | <a href="https://twitter.com/" style="color: #1da1f2;">Twitter</a> |
# | Instagram    | <a href="https://www.instagram.com/" style="color: #c13584;">Instagram</a> |
# | LinkedIn     | <a href="https://www.linkedin.com/" style="color: #0077b5;">LinkedIn</a> |
# | YouTube      | <a href="https://www.youtube.com/" style="color: #ff0000;">YouTube</a> |

# %% [markdown]
# <style>
#   .facebook { background-color: #3b5998; }
#   .twitter { background-color: #1da1f2; }
#   .instagram { background-color: #c13584; }
#   .linkedin { background-color: #0077b5; }
#   .youtube { background-color: #ff0000; }
# </style>
#
# | Social Media | Link |
# |--------------|------|
# | Facebook     | <a href="https://www.facebook.com/" class="facebook" style="color: white;">Facebook</a> |
# | Twitter      | <a href="https://twitter.com/" class="twitter" style="color: white;">Twitter</a> |
# | Instagram    | <a href="https://www.instagram.com/" class="instagram" style="color: white;">Instagram</a> |
# | LinkedIn     | <a href="https://www.linkedin.com/" class="linkedin" style="color: white;">LinkedIn</a> |
# | YouTube      | <a href="https://www.youtube.com/" class="youtube" style="color: white;">YouTube</a> |

# %% [markdown]
# <style>
#   .facebook { background-color: #3b5998; }
#   .twitter { background-color: #1da1f2; }
#   .instagram { background-color: #c13584; }
#   .linkedin { background-color: #0077b5; }
#   .youtube { background-color: #ff0000:}
#   .medium  { background-color: #12100c; color: white;}
#
#
# </style>
#
# <table>
#   <tr>
#     <th>Social Media</th>
#     <th>Link</th>
#   </tr>
#   <tr>
#     <td class="facebook" style="color: white;">Facebook</td>
#     <td><a href="https://www.facebook.com/" class="facebook" style="color: white;">Facebook</a></td>
#   </tr>
#   <tr>
#     <td class="twitter" style="color: white;">Twitter</td>
#     <td><a href="https://twitter.com/" class="twitter" style="color: white;">Twitter</a></td>
#   </tr>
#   <tr>
#     <td class="instagram" style="color: white;">Instagram</td>
#     <td><a href="https://www.instagram.com/" class="instagram" style="color: white;">Instagram</a></td>
#   </tr>
#   <tr>
#     <td class="linkedin" style="color: white;">LinkedIn</td>
#     <td><a href="https://www.linkedin.com/" class="linkedin" style="color: white;">LinkedIn</a></td>
#   </tr>
#   <tr>
#     <td class="youtube" style="color: white;">YouTube</td>
#     <td><a href="https://www.youtube.com/" class="youtube" style="color: white;">YouTube</a></td>
#   </tr>
#   <tr>
#     <td class ="medium" style="color: white;">Medium Blog</td>
#     <td><a href="https://medium.com/@juliannatali" class="medium"> Medium Blog</a></td>
#   </tr>
# </table>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Social Media Links</title>
# <style>
#   .facebook { background-color: #3b5998; }
#   .twitter { background-color: #1da1f2; }
#   .instagram { background-color: #c13584; }
#   .linkedin { background-color: #0077b5; }
#   .youtube { background-color: #ff0000; }
# </style>
# </head>
# <body>
#
# <table>
#   <thead>
#     <tr>
#       <th>Social Media</th>
#       <th>Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Facebook</td>
#       <td><a href="https://www.facebook.com/" class="facebook" style="color: white;">Facebook</a></td>
#     </tr>
#     <tr>
#       <td>Twitter</td>
#       <td><a href="https://twitter.com/" class="twitter" style="color: white;">Twitter</a></td>
#     </tr>
#     <tr>
#       <td>Instagram</td>
#       <td><a href="https://www.instagram.com/" class="instagram" style="color: white;">Instagram</a></td>
#     </tr>
#     <tr>
#       <td>LinkedIn</td>
#       <td><a href="https://www.linkedin.com/" class="linkedin" style="color: white;">LinkedIn</a></td>
#     </tr>
#     <tr>
#       <td>YouTube</td>
#       <td><a href="https://www.youtube.com/" class="youtube" style="color: white;">YouTube</a></td>
#     </tr>
#   </tbody>
# </table>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Social Media Links</title>
# <style>
#   .facebook { background-color: #3b5998; }
#   .twitter { background-color: #1da1f2; }
#   .instagram { background-color: #c13584; }
#   .linkedin { background-color: #0077b5; }
#   .youtube { background-color: #ff0000; }
#   .medium  { background-color: #12100c; color: white; }
#   .email   { background-color: #60bd63; }
#   /* Ensuring link fills entire cell */
#   table td a { display: block; width: 100%; height: 100%; }
# </style>
# </head>
# <body>
#
# <table>
#   <tr>
#     <th>Social Media</th>
#     <th>Link</th>
#   </tr>
#   <tr>
#     <td class="facebook" style="color: white;">Facebook</td>
#     <td><a href="https://www.facebook.com/" class="facebook" style="color: white;">Facebook</a></td>
#   </tr>
#   <tr>
#     <td class="twitter" style="color: white;">Twitter</td>
#     <td><a href="https://twitter.com/" class="twitter" style="color: white;">Twitter</a></td>
#   </tr>
#   <tr>
#     <td class="instagram" style="color: white;">Instagram</td>
#     <td><a href="https://www.instagram.com/" class="instagram" style="color: white;">Instagram</a></td>
#   </tr>
#   <tr>
#     <td class="linkedin" style="color: white;">LinkedIn</td>
#     <td><a href="https://www.linkedin.com/" class="linkedin" style="color: white;">LinkedIn</a></td>
#   </tr>
#   <tr>
#     <td class="youtube" style="color: white;">YouTube</td>
#     <td><a href="https://www.youtube.com/" class="youtube" style="color: white;">YouTube</a></td>
#   </tr>
#   <tr>
#     <td class="medium" style="color: white;">Medium Blog</td>
#     <td><a href="https://medium.com/@juliannatali" class="medium">Medium Blog</a></td>
#   </tr>
#   <tr>
#     <td class="email" style="color: white;">Email Mail</td>
#     <td><a href="mailto:<umarmehmood885@gmail.com>" class="email" style="color: white;">Email Mail</a></td>
#   </tr>
# </table>
#
# </body>
# </html>

# %% [markdown]
# <h1 style="color: #FF9900;">Data Science Exploration</h1>

# %% [markdown]
# <table>
#   <tr>
#     <th>Attribute</th>
#     <th>Value</th>
#   </tr>
#   <tr>
#     <td>Height</td>
#     <td>200px</td>
#   </tr>
#   <tr>
#     <td>Width</td>
#     <td>300px</td>
#   </tr>
# </table>

# %% [markdown]
# <h1 style="color: blue;">Data Science Exploration</h1>
#
# <table>
#   <tr><th>Name</th><td>John Doe</td></tr>
#   <tr><th>Age</th><td>32</td></tr>
#   <tr><th rowspan=2>Country of Residence<br/>(with multiple lines)</th><td>United States of America</td></tr>

# %% [markdown]
# <h1 style="color: #FF9900; background-color: #334445;">Data Science Exploration</h1>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; height: 50px; width: 500px; background-color: blue;">
#   <h1 style="color: #FF9900; font-size: 20px; min-width: 0;">Data Science Exploration</h1>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 100px; min-width: 500px; background-color: blue;">
#   <h1 style="color: #FF9900;">Data Science Exploration</h1>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 200px; background-color: blue;">
#   <h1 style="color: #FF9900; font-size: 20px; min-width: 0;">Data Science Exploration</h1>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; height: 50px; width: 500px; background-color: blue;  background-repeat: repeat;">
#   <h1 style="color: #FF9900; font-size: 20px; min-width: 0;">Data Science Exploration</h1>
# </div>
