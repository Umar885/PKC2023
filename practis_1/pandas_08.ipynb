# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
df = pd.read_excel("pandas_01.xlsx")

# %%
df.head()
# Out:
#    index                merchantid  listedproducts  totalunitssold
# 0      0  5357bcf2bb72c5504882e889               2          120000  \
# 1      1  5708773c3c02161b3f8c7900               5          107100
# 2      2  5417aada4ad3ab27e954b76c               2          100007
# 3      3  570f3a713a698c14278bb51e               1          100000
# 4      4  53082ea15aefb07dfe1f2a4f               1          100000
#
#    meanunitssoldperproduct  rating  merchantratingscount  meanproductprices
# 0                    60000   4.219                320031               9.00  \
# 1                    21420   3.934                139223               7.76
# 2                    50004   4.053                108048               8.00
# 3                   100000   3.889                 19248               5.67
# 4                   100000   4.036                366898               5.00
#
#    meanretailprices  averagediscount  meandiscount  meanproductratingscount
# 0              20.0               54          54.0                     8836  \
# 1              34.2               61          61.0                     4010
# 2               8.0               -1          -1.0                     5531
# 3              19.0               71          71.0                    18393
# 4              33.0               85          85.0                    13789
#
#    totalurgencycount  urgencytextrate
# 0                1.0             50.0
# 1                3.0             60.0
# 2                NaN              NaN
# 3                1.0            100.0
# 4                NaN              NaN

# %%
df.loc[::-1].head()
# Out:
#      index                merchantid  listedproducts  totalunitssold
# 957    957  5d4b8931933fb13f8a1fe232               1               1  \
# 956    956  5add589edb5f1f32114d07df               1               1
# 955    955  5d417e7070327a2743021677               1               1
# 954    954  5b24edf0d1c360301099e9c6               1               2
# 953    953  567bad8582c35f28103e5813               1               2
#
#      meanunitssoldperproduct  rating  merchantratingscount  meanproductprices
# 957                        1   4.007                  1380              11.00  \
# 956                        1   3.956                  1134              14.00
# 955                        1   3.598                   378               2.72
# 954                        2   4.303                   693              16.00
# 953                        2   3.999                 21307              11.00
#
#      meanretailprices  averagediscount  meandiscount  meanproductratingscount
# 957              30.0               64          64.0                        0  \
# 956              14.0                0           0.0                        0
# 955               9.0               70          70.0                        0
# 954              16.0                0           0.0                        0
# 953              10.0              -10         -10.0                        1
#
#      totalurgencycount  urgencytextrate
# 957                NaN              NaN
# 956                NaN              NaN
# 955                NaN              NaN
# 954                NaN              NaN
# 953                NaN              NaN

# %%
df.loc[::-1].reset_index(drop=True).head()
# Out:
#    index                merchantid  listedproducts  totalunitssold
# 0    957  5d4b8931933fb13f8a1fe232               1               1  \
# 1    956  5add589edb5f1f32114d07df               1               1
# 2    955  5d417e7070327a2743021677               1               1
# 3    954  5b24edf0d1c360301099e9c6               1               2
# 4    953  567bad8582c35f28103e5813               1               2
#
#    meanunitssoldperproduct  rating  merchantratingscount  meanproductprices
# 0                        1   4.007                  1380              11.00  \
# 1                        1   3.956                  1134              14.00
# 2                        1   3.598                   378               2.72
# 3                        2   4.303                   693              16.00
# 4                        2   3.999                 21307              11.00
#
#    meanretailprices  averagediscount  meandiscount  meanproductratingscount
# 0              30.0               64          64.0                        0  \
# 1              14.0                0           0.0                        0
# 2               9.0               70          70.0                        0
# 3              16.0                0           0.0                        0
# 4              10.0              -10         -10.0                        1
#
#    totalurgencycount  urgencytextrate
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN

# %%
df.dtypes
# Out:
# index                        int64
# merchantid                  object
# listedproducts               int64
# totalunitssold               int64
# meanunitssoldperproduct      int64
# rating                     float64
# merchantratingscount         int64
# meanproductprices          float64
# meanretailprices           float64
# averagediscount              int64
# meandiscount               float64
# meanproductratingscount      int64
# totalurgencycount          float64
# urgencytextrate            float64
# dtype: object

# %%
df.select_dtypes(include=['number']).head()
# Out:
#    index  listedproducts  totalunitssold  meanunitssoldperproduct  rating
# 0      0               2          120000                    60000   4.219  \
# 1      1               5          107100                    21420   3.934
# 2      2               2          100007                    50004   4.053
# 3      3               1          100000                   100000   3.889
# 4      4               1          100000                   100000   4.036
#
#    merchantratingscount  meanproductprices  meanretailprices  averagediscount
# 0                320031               9.00              20.0               54  \
# 1                139223               7.76              34.2               61
# 2                108048               8.00               8.0               -1
# 3                 19248               5.67              19.0               71
# 4                366898               5.00              33.0               85
#
#    meandiscount  meanproductratingscount  totalurgencycount  urgencytextrate
# 0          54.0                     8836                1.0             50.0
# 1          61.0                     4010                3.0             60.0
# 2          -1.0                     5531                NaN              NaN
# 3          71.0                    18393                1.0            100.0
# 4          85.0                    13789                NaN              NaN

# %%
df.select_dtypes(include=['float']).head()
# Out:
#    rating  meanproductprices  meanretailprices  meandiscount
# 0   4.219               9.00              20.0          54.0  \
# 1   3.934               7.76              34.2          61.0
# 2   4.053               8.00               8.0          -1.0
# 3   3.889               5.67              19.0          71.0
# 4   4.036               5.00              33.0          85.0
#
#    totalurgencycount  urgencytextrate
# 0                1.0             50.0
# 1                3.0             60.0
# 2                NaN              NaN
# 3                1.0            100.0
# 4                NaN              NaN

# %%
df.select_dtypes(include=['object']).head()
# Out:
#                  merchantid
# 0  5357bcf2bb72c5504882e889
# 1  5708773c3c02161b3f8c7900
# 2  5417aada4ad3ab27e954b76c
# 3  570f3a713a698c14278bb51e
# 4  53082ea15aefb07dfe1f2a4f

# %%
df.select_dtypes(exclude=['object']).head()
# Out:
#    index  listedproducts  totalunitssold  meanunitssoldperproduct  rating
# 0      0               2          120000                    60000   4.219  \
# 1      1               5          107100                    21420   3.934
# 2      2               2          100007                    50004   4.053
# 3      3               1          100000                   100000   3.889
# 4      4               1          100000                   100000   4.036
#
#    merchantratingscount  meanproductprices  meanretailprices  averagediscount
# 0                320031               9.00              20.0               54  \
# 1                139223               7.76              34.2               61
# 2                108048               8.00               8.0               -1
# 3                 19248               5.67              19.0               71
# 4                366898               5.00              33.0               85
#
#    meandiscount  meanproductratingscount  totalurgencycount  urgencytextrate
# 0          54.0                     8836                1.0             50.0
# 1          61.0                     4010                3.0             60.0
# 2          -1.0                     5531                NaN              NaN
# 3          71.0                    18393                1.0            100.0
# 4          85.0                    13789                NaN              NaN

# %%
df.sample(frac=0.1).shape
# Out:
# (96, 14)

# %%
df = pd.read_clipboard() 
df
# Out:
#     index                merchantid  listedproducts totalunitssold
# 0       0  5357bcf2bb72c5504882e889               2        120,000  \
# 1       1  5708773c3c02161b3f8c7900               5        107,100
# 2       2  5417aada4ad3ab27e954b76c               2        100,007
# 3       3  570f3a713a698c14278bb51e               1        100,000
# 4       4  53082ea15aefb07dfe1f2a4f               1        100,000
# 5       5  53f2beb39020ee03566d6e18               1        100,000
# 6       6  5926c5ace8ff5525241b368d               7         96,000
# 7       7  5860c757b1e41d4d67d183e8               4         90,100
# 8       8  52bd3ddb34067e4620a4c62d               3         80,000
# 9       9  5a7b23a69bda4e3d375e7b3f               5         80,000
# 10     10  53a2a09ad91139519161a267               3         75,000
# 11     11  539937d634067e06707b1a8e               4         71,100
# 12     12  58ad449708de0c6dc59d9e06               6         63,100
#
#    meanunitssoldperproduct  rating merchantratingscount  meanproductprices
# 0                   60,000    4.22              320,031               9.00
# 1                   21,420    3.93              139,223               7.76
# 2                   50,004    4.05              108,048               8.00
# 3                  100,000    3.89               19,248               5.67
# 4                  100,000    4.04              366,898               5.00
# 5                  100,000    4.07              330,405               5.77
# 6                   13,714    4.14               55,499               6.69
# 7                   22,525    4.05              151,249               3.43
# 8                   26,667    4.10              839,882               7.22
# 9                   16,000    3.97               12,974               8.40
# 10                  25,000    4.26              165,915              13.33
# 11                  17,775    3.97               51,369              11.50
# 12                  10,517    4.15              126,370               3.61

# %%
kashti_1 = df.sample(frac=0.50, random_state=1)
kashti_1.shape
# Out:
# (6, 8)

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
df = pd.read_excel("pandas_01.xlsx")

# %%
kashti_1 = df.sample(frac=0.50, random_state=1)
kashti_1.shape
# Out:
# (479, 14)

# %%
df.loc[::-1].head()
df.loc[::-1].reset_index(drop=True).head()

# %%
df.select_dtypes(include=['number']).head()
df.select_dtypes(include=['float']).head()
df.select_dtypes(exclude=['object']).head()
df.sample(frac=0.1).shape
df = pd.read_clipboard() 
kashti_1 = df.sample(frac=0.50, random_state=1)
